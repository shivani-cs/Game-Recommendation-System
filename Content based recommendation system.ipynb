# %% [markdown]
# ### Import Libraries

# %%
import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %% [markdown]
# ### Loading Data

# %%
# Get games data from CSV
dataGames = pd.read_csv('data/cleaned/processed_games_for_content-based.csv')

# %%
# Creating the dataframe 
cursor = mycol.find()
dataGames =  pd.DataFrame(list(cursor))
del dataGames['_id']
dataGames.head(5)
# Out:
#                             name           developer  \
# 0                           DOOM          idSoftware
# 1  PLAYERUNKNOWN'S BATTLEGROUNDS     PUBGCorporation
# 2                     BATTLETECH  HarebrainedSchemes
# 3                           DayZ  BohemiaInteractive
# 4                     EVE Online                 CCP
#
#                                publisher  \
# 0    BethesdaSoftworks,BethesdaSoftworks
# 1        PUBGCorporation,PUBGCorporation
# 2  ParadoxInteractive,ParadoxInteractive
# 3  BohemiaInteractive,BohemiaInteractive
# 4                                CCP,CCP
#
#                                         popular_tags  \
# 0  FPS,Gore,Action,Demons,Shooter,First-Person,Gr...
# 1  Survival,Shooter,Multiplayer,BattleRoyale,PvP,...
# 2  Mechs,Strategy,Turn-Based,Turn-BasedTactics,Sc...
# 3  Survival,Zombies,OpenWorld,Multiplayer,PvP,Mas...
# 4  Space,MassivelyMultiplayer,Sci-fi,Sandbox,MMOR...
#
#                                         game_details  \
# 0  Single-player,Multi-player,Co-op,SteamAchievem...
# 1              Multi-player,OnlineMulti-Player,Stats
# 2  Single-player,Multi-player,OnlineMulti-Player,...
# 3  Multi-player,OnlineMulti-Player,SteamWorkshop,...
# 4  Multi-player,OnlineMulti-Player,MMO,Co-op,Onli...
#
#                                                genre original_price  \
# 0                                             Action         $19.99
# 1              Action,Adventure,MassivelyMultiplayer         $29.99
# 2                          Action,Adventure,Strategy         $39.99
# 3              Action,Adventure,MassivelyMultiplayer         $44.99
# 4  Action,FreetoPlay,MassivelyMultiplayer,RPG,Str...           Free
#
#   discount_price review_qualification  percentage_positive_review  \
# 0         $14.99        Very Positive                          92
# 1            NaN                Mixed                          49
# 2            NaN      Mostly Positive                          71
# 3            NaN                Mixed                          61
# 4            NaN      Mostly Positive                          74
#
#                             ID  \
# 0                         doom
# 1  playerunknownsbattlegrounds
# 2                   battletech
# 3                         dayz
# 4                    eveonline
#
#                            genre_publisher_developer
# 0                Action,idSoftware,BethesdaSoftworks
# 1  Action,Adventure,MassivelyMultiplayer,PUBGCorp...
# 2  Adventure,Action,ParadoxInteractive,Strategy,H...
# 3  Action,Adventure,BohemiaInteractive,MassivelyM...
# 4  Action,MassivelyMultiplayer,CCP,RPG,Strategy,F...

# %%
dataGames.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40833 entries, 0 to 40832
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   name                        40833 non-null  object
#  1   developer                   40833 non-null  object
#  2   publisher                   40833 non-null  object
#  3   popular_tags                40833 non-null  object
#  4   game_details                40833 non-null  object
#  5   genre                       40833 non-null  object
#  6   original_price              35522 non-null  object
#  7   discount_price              14543 non-null  object
#  8   review_qualification        17363 non-null  object
#  9   percentage_positive_review  40833 non-null  int64
#  10  ID                          40833 non-null  object
#  11  genre_publisher_developer   40833 non-null  object
# dtypes: int64(1), object(11)
# memory usage: 3.7+ MB

# %%
# Construct a reverse map of indices and game names
indices = pd.Series(dataGames.index, index=dataGames['name']).drop_duplicates()

# %%
# get list of games we have info about
listGames = dataGames['name'].unique()
len(listGames)
# Out:
# 40750

# %% [markdown]
# ### Content based Recommendation

# %%
# create dataframe for recommendations
n_recommendation = 20
col_names = list(map(str, range(1, n_recommendation + 1)))
col_names = ["user_id"] + col_names

# %%
# Function that takes in game name and Cosine Similarity matrix as input and outputs most similar games
def get_recommendations(title, cosine_sim):

    if title not in listGames:
        return []

    # Get the index of the game that matches the name
    idx = indices[title]

    # if there's 2 games or more with same name (game RUSH)
    if type(idx) is pd.Series:
        return []

    # Get the pairwise similarity scores of all games with that game
    sim_scores = list(enumerate(cosine_sim[idx]))

    # Sort the games based on the similarity scores
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)

    # Get the scores of the most similar games
    # (not the first one because this games as a score of 1 (perfect score) similarity with itself)
    sim_scores = sim_scores[1:n_recommendation + 1]

    # Get the games indices
    game_indices = [i[0] for i in sim_scores]

    # Return the top most similar games
    return dataGames['name'].iloc[game_indices].tolist()

# %%
def generate_recommendation_output(column_name):

    # need to do some modification on data to make sure there is no NaN in column
    dataGames[column_name] = dataGames[column_name].fillna('')
    # Compute the Cosine Similarity matrix using the column
    count = CountVectorizer(stop_words='english')
    count_matrix = count.fit_transform(dataGames[column_name])
    cosine_sim_matrix = cosine_similarity(count_matrix, count_matrix)

    return cosine_sim_matrix

# %%
similarity_matrix = generate_recommendation_output('genre_publisher_developer')

# %%
import numpy as np
np.shape(similarity_matrix)
# Out:
# (40833, 40833)

# %%
from bson.binary import Binary
with open('test.npy', 'wb') as f:
    np.save(f, similarity_matrix)

# %%
# mycol = mydb["recommendation_matrix"]
# record['name'] = "Steam Content Based"

# %% [markdown]
# ### Similar games

# %% [markdown]
# #### Example 1

# %%
recommendations = get_recommendations('Dota 2', similarity_matrix)

# %%
dataGames[dataGames['name'] == 'Dota 2']
# Out:
#        name developer    publisher  \
# 419  Dota 2     Valve  Valve,Valve
#
#                                           popular_tags  \
# 419  FreetoPlay,MOBA,Multiplayer,Strategy,e-sports,...
#
#                                           game_details  \
# 419  Multi-player,Co-op,SteamTradingCards,SteamWork...
#
#                           genre original_price discount_price  \
# 419  Action,FreetoPlay,Strategy   Free to Play         $65.70
#
#     review_qualification  percentage_positive_review     ID  \
# 419        Very Positive                          85  dota2
#
#             genre_publisher_developer
# 419  Action,FreetoPlay,Strategy,Valve

# %%
dataGames[dataGames['name'].isin(recommendations)]
# Out:
#                                                  name  \
# 26                                             Portal
# 42                             Counter-Strike: Source
# 271                                     Left 4 Dead 2
# 386                                   Team Fortress 2
# 422                  Counter-Strike: Global Offensive
# 593                                       Half-Life 2
# 596                                         Half-Life
# 767                                Left 4 Dead Bundle
# 990                                 Bloons TD Battles
# 1208                                   The Orange Box
# 1615                              Valve Complete Pack
# 8565        Fight Songs: The Music Of Team Fortress 2
# 8596               The International 2019 Battle Pass
# 8602                    The Defender: Farm and Castle
# 22180                         Winions: Mana Champions
# 22541  The International 2019 Battle Pass - Level 100
# 27641                                     Arena Stars
# 29517   The International 2019 Battle Pass - Level 50
# 36636               Games of Glory - "Guardians Pack"
# 36960           Dropzone - Pilot Pack: Threshing Trio
#
#                            developer  \
# 26                             Valve
# 42                             Valve
# 271                            Valve
# 386                            Valve
# 422    Valve,HiddenPathEntertainment
# 593                            Valve
# 596                            Valve
# 767                            Valve
# 990                        NinjaKiwi
# 1208                           Valve
# 1615                           Valve
# 8565                           Valve
# 8596                           Valve
# 8602                 KittiSarmuerjai
# 22180                     FueroGames
# 22541                          Valve
# 27641               TinyTitanStudios
# 29517                          Valve
# 36636                  LightbulbCrew
# 36960          SparkypantsStudiosLLC
#
#                                          publisher  \
# 26                                     Valve,Valve
# 42                                     Valve,Valve
# 271                                    Valve,Valve
# 386                                    Valve,Valve
# 422                                    Valve,Valve
# 593                                    Valve,Valve
# 596                                    Valve,Valve
# 767                                          Valve
# 990                            NinjaKiwi,NinjaKiwi
# 1208                                         Valve
# 1615                                         Valve
# 8565                                   Valve,Valve
# 8596                                   Valve,Valve
# 8602               KittiSarmuerjai,KittiSarmuerjai
# 22180                        FueroGames,FueroGames
# 22541                                          NaN
# 27641            TinyTitanStudios,TinyTitanStudios
# 29517                                          NaN
# 36636                  LightbulbCrew,LightbulbCrew
# 36960  SparkypantsStudiosLLC,SparkypantsStudiosLLC
#
#                                             popular_tags  \
# 26     Puzzle,First-Person,Singleplayer,Sci-fi,Comedy...
# 42     Shooter,Action,FPS,Multiplayer,Team-Based,Firs...
# 271    Zombies,Co-op,FPS,Multiplayer,Shooter,Action,O...
# 386    FreetoPlay,Multiplayer,FPS,Shooter,Action,Clas...
# 422    FPS,Shooter,Multiplayer,Competitive,Action,Tea...
# 593    FPS,Action,Sci-fi,Classic,Singleplayer,Masterp...
# 596    FPS,Classic,Action,Sci-fi,Singleplayer,Masterp...
# 767                                                  NaN
# 990    FreetoPlay,TowerDefense,Multiplayer,Strategy,A...
# 1208                                                 NaN
# 1615                                                 NaN
# 8565   Action,FreetoPlay,GreatSoundtrack,Music,Soundt...
# 8596                          Action,Strategy,FreetoPlay
# 8602   FreetoPlay,TowerDefense,Strategy,Action,2D,Sin...
# 22180                         FreetoPlay,Strategy,Action
# 22541                         FreetoPlay,Strategy,Action
# 27641                FreetoPlay,Strategy,Action,MOBA,PvP
# 29517                         Action,Strategy,FreetoPlay
# 36636                         Strategy,Action,FreetoPlay
# 36960                         Strategy,Action,FreetoPlay
#
#                                             game_details  \
# 26     Single-player,SteamAchievements,Captionsavaila...
# 42     Multi-player,Cross-PlatformMultiplayer,SteamAc...
# 271    Single-player,Multi-player,Co-op,SteamAchievem...
# 386    Multi-player,Cross-PlatformMultiplayer,SteamAc...
# 422    Multi-player,SteamAchievements,Fullcontrollers...
# 593    Single-player,SteamAchievements,SteamTradingCa...
# 596    Single-player,Multi-player,OnlineMulti-Player,...
# 767    Single-player,Multi-player,Co-op,SteamAchievem...
# 990    Cross-PlatformMultiplayer,SteamAchievements,St...
# 1208   Single-player,Multi-player,Cross-PlatformMulti...
# 1615   Single-player,Multi-player,OnlineMulti-Player,...
# 8565   Multi-player,Cross-PlatformMultiplayer,Downloa...
# 8596   Multi-player,Co-op,DownloadableContent,SteamTr...
# 8602   Single-player,Steamislearningaboutthisgame \r\...
# 22180  Multi-player,OnlineMulti-Player,Cross-Platform...
# 22541  Multi-player,Co-op,DownloadableContent,SteamTr...
# 27641  OnlineMulti-Player,SteamAchievements,Fullcontr...
# 29517  Multi-player,Co-op,DownloadableContent,SteamTr...
# 36636  DownloadableContent,ProfileFeaturesLimited \r\...
# 36960  Single-player,Multi-player,OnlineMulti-Player,...
#
#                                       genre original_price discount_price  \
# 26                                   Action          $9.99         $14.98
# 42                                   Action          $9.99         $65.70
# 271                                  Action          $9.99         $14.98
# 386                       Action,FreetoPlay   Free to Play         $65.70
# 422                       Action,FreetoPlay   Free to Play         $65.70
# 593                                  Action          $9.99         $65.70
# 596                                  Action          $9.99         $65.70
# 767                                  Action            NaN         $14.98
# 990              Action,FreetoPlay,Strategy   Free to Play            NaN
# 1208                      Action,FreetoPlay         $19.99          $9.99
# 1615   Action,Adventure,FreetoPlay,Strategy            NaN         $65.70
# 8565                      Action,FreetoPlay         $12.99            NaN
# 8596             Action,FreetoPlay,Strategy          $9.99            NaN
# 8602             Action,FreetoPlay,Strategy   Free To Play            NaN
# 22180            Action,FreetoPlay,Strategy   Free To Play            NaN
# 22541            Action,FreetoPlay,Strategy         $44.99            NaN
# 27641            Action,FreetoPlay,Strategy   Free To Play            NaN
# 29517            Action,FreetoPlay,Strategy         $29.35            NaN
# 36636            Action,FreetoPlay,Strategy          $9.99            NaN
# 36960            Action,FreetoPlay,Strategy          $9.99            NaN
#
#           review_qualification  percentage_positive_review  \
# 26     Overwhelmingly Positive                          97
# 42     Overwhelmingly Positive                          95
# 271    Overwhelmingly Positive                          96
# 386              Very Positive                          93
# 422              Very Positive                          86
# 593    Overwhelmingly Positive                          96
# 596    Overwhelmingly Positive                          95
# 767                        NaN                          -1
# 990              Very Positive                          84
# 1208                       NaN                          -1
# 1615                       NaN                          -1
# 8565             Very Positive                          90
# 8596             Very Positive                          83
# 8602             Very Positive                          90
# 22180                    Mixed                          50
# 22541                    Mixed                          62
# 27641                    Mixed                          68
# 29517                      NaN                          -1
# 36636                      NaN                          -1
# 36960                      NaN                          -1
#
#                                            ID  \
# 26                                     portal
# 42                        counterstrikesource
# 271                                left4dead2
# 386                             teamfortress2
# 422              counterstrikeglobaloffensive
# 593                                 halflife2
# 596                                  halflife
# 767                           left4deadbundle
# 990                           bloonstdbattles
# 1208                             theorangebox
# 1615                        valvecompletepack
# 8565        fightsongsthemusicofteamfortress2
# 8596           theinternational2019battlepass
# 8602                 thedefenderfarmandcastle
# 22180                    winionsmanachampions
# 22541  theinternational2019battlepasslevel100
# 27641                              arenastars
# 29517   theinternational2019battlepasslevel50
# 36636               gamesofgloryguardianspack
# 36960          dropzonepilotpackthreshingtrio
#
#                               genre_publisher_developer
# 26                                         Action,Valve
# 42                                         Action,Valve
# 271                                        Action,Valve
# 386                             Action,FreetoPlay,Valve
# 422     Action,FreetoPlay,HiddenPathEntertainment,Valve
# 593                                        Action,Valve
# 596                                        Action,Valve
# 767                                        Action,Valve
# 990                Action,NinjaKiwi,FreetoPlay,Strategy
# 1208                            Action,FreetoPlay,Valve
# 1615         Adventure,Valve,Action,Strategy,FreetoPlay
# 8565                            Action,FreetoPlay,Valve
# 8596                   Action,FreetoPlay,Strategy,Valve
# 8602         KittiSarmuerjai,Action,FreetoPlay,Strategy
# 22180             Action,FreetoPlay,Strategy,FueroGames
# 22541                 ,Valve,Action,Strategy,FreetoPlay
# 27641       Action,TinyTitanStudios,FreetoPlay,Strategy
# 29517                 ,Valve,Action,Strategy,FreetoPlay
# 36636          Action,LightbulbCrew,FreetoPlay,Strategy
# 36960  Action,FreetoPlay,Strategy,SparkypantsStudiosLLC

# %% [markdown]
# #### Example 2

# %%
recommendations = get_recommendations('Starbound', similarity_matrix)

# %%
dataGames[dataGames['name'] == 'Starbound']
# Out:
#           name    developer                publisher  \
# 303  Starbound  Chucklefish  Chucklefish,Chucklefish
#
#                                           popular_tags  \
# 303  Sandbox,Survival,Adventure,Space,Crafting,Indi...
#
#                                           game_details  \
# 303  Single-player,Multi-player,OnlineMulti-Player,...
#
#                                  genre original_price discount_price  \
# 303  Action,Adventure,Casual,Indie,RPG         $14.99         $79.84
#
#     review_qualification  percentage_positive_review         ID  \
# 303        Very Positive                          90  starbound
#
#                          genre_publisher_developer
# 303  Adventure,Action,Chucklefish,Indie,RPG,Casual

# %%
dataGames[dataGames['name'].isin(recommendations)]
# Out:
#                                                    name  \
# 73                                     Castle Crashers®
# 964                                         Bladed Fury
# 1161                                        Timespinner
# 2308                                     Book of Demons
# 3432                     Ages of Mages: The last keeper
# 4016                                           Ara Fell
# 4457                   Dabman: When the Haters Dab Back
# 4481                       Chucklefish & Friends Bundle
# 5886                                       Loot Hero DX
# 5951                                XGen Studios Bundle
# 6408               The Black & White Indie Games Bundle
# 6824                                Stately Snail Games
# 7030                      Aidsmoji: The Forbidden Fruit
# 7135                                    Doomster Bundle
# 7202                     Camp Sunshine Ultimate Edition
# 7203                                 CAPSLOCKDAY Bundle
# 7557         Book of Demons to Supporter's Pack Upgrade
# 7699          Super Cane Magic ZERO: Soundtrack Edition
# 7850  Star Story: Game + OST + Artbook (Devs support...
# 8057                          Supernatural Indie Bundle
#
#                   developer                      publisher  \
# 73              TheBehemoth        TheBehemoth,TheBehemoth
# 964             NEXTStudios        NEXTStudios,NEXTStudios
# 1161          LunarRayGames        Chucklefish,Chucklefish
# 2308             ThingTrunk          ThingTrunk,ThingTrunk
# 3432               YFCgames              YFCgames,YFCgames
# 4016         StegosoftGames  StegosoftGames,StegosoftGames
# 4457              BmcStudio            BmcStudio,BmcStudio
# 4481             Robotality                    Chucklefish
# 5886                VaragtP                VaragtP,VaragtP
# 5951            XGenStudios                    XGenStudios
# 6408               Playdead                       Playdead
# 6824           StatelySnail                   StatelySnail
# 7030              BmcStudio            BmcStudio,BmcStudio
# 7135  DoomsterEntertainment          DoomsterEntertainment
# 7202            FossilGames                    FossilGames
# 7203             DylanLoney                     DylanLoney
# 7557             ThingTrunk                     ThingTrunk
# 7699             StudioEvil                     StudioEvil
# 7850            EvilCoGames                    EvilCoGames
# 8057   AsteristicGameStudio           AsteristicGameStudio
#
#                                            popular_tags  \
# 73    Co-op,Action,Multiplayer,Adventure,LocalCo-Op,...
# 964   Action,FemaleProtagonist,Indie,Violent,Adventu...
# 1161  Metroidvania,Indie,RPG,Adventure,Action,Female...
# 2308  DungeonCrawler,HackandSlash,Singleplayer,RPG,I...
# 3432  RPG,Indie,Action,Adventure,Casual,LocalCo-Op,L...
# 4016  RPG,RPGMaker,Indie,Adventure,JRPG,FemaleProtag...
# 4457  Casual,Action,Adventure,PsychologicalHorror,Me...
# 4481                                                NaN
# 5886  Casual,Indie,RPG,Action,Adventure,Clicker,Pixe...
# 5951                                                NaN
# 6408                                                NaN
# 6824                                                NaN
# 7030  Casual,Indie,Action,Adventure,RPG,Psychologica...
# 7135                                                NaN
# 7202                                                NaN
# 7203                                                NaN
# 7557                                                NaN
# 7699                                                NaN
# 7850                                                NaN
# 8057                                                NaN
#
#                                            game_details  \
# 73    Single-player,Multi-player,OnlineMulti-Player,...
# 964   Single-player,SteamAchievements,Fullcontroller...
# 1161  Single-player,LocalCo-op,SteamAchievements,Ful...
# 2308  Single-player,SteamAchievements,Fullcontroller...
# 3432  Single-player,LocalMulti-Player,LocalCo-op,Sha...
# 4016  Single-player,Fullcontrollersupport,SteamTradi...
# 4457  Single-player,ProfileFeaturesLimited \r\n\t\t\...
# 4481  Single-player,Multi-player,OnlineMulti-Player,...
# 5886  Single-player,SteamAchievements,Fullcontroller...
# 5951  Single-player,Shared/SplitScreen,SteamAchievem...
# 6408  Single-player,SteamAchievements,Fullcontroller...
# 6824  Single-player,SteamAchievements,Fullcontroller...
# 7030                                      Single-player
# 7135  Single-player,OnlineCo-op,LocalCo-op,Shared/Sp...
# 7202  Single-player,DownloadableContent,SteamTrading...
# 7203  Single-player,Multi-player,Cross-PlatformMulti...
# 7557  Single-player,DownloadableContent,SteamAchieve...
# 7699  Single-player,LocalMulti-Player,LocalCo-op,Sha...
# 7850  Single-player,DownloadableContent,SteamAchieve...
# 8057  Single-player,DownloadableContent,SteamAchieve...
#
#                                            genre original_price  \
# 73             Action,Adventure,Casual,Indie,RPG         $14.99
# 964            Action,Adventure,Casual,Indie,RPG          $9.99
# 1161                  Action,Adventure,Indie,RPG         $19.99
# 2308           Action,Adventure,Casual,Indie,RPG         $24.99
# 3432           Action,Adventure,Casual,Indie,RPG         $11.99
# 4016           Action,Adventure,Casual,Indie,RPG          $9.99
# 4457           Action,Adventure,Casual,Indie,RPG         $36.87
# 4481  Action,Indie,RPG,Strategy,Adventure,Casual            NaN
# 5886           Action,Adventure,Casual,Indie,RPG          $2.99
# 5951           Adventure,Casual,Indie,RPG,Action            NaN
# 6408           Adventure,Indie,Action,Casual,RPG            NaN
# 6824           Action,Indie,RPG,Casual,Adventure         $19.95
# 7030           Action,Adventure,Casual,Indie,RPG         $36.87
# 7135           Indie,Adventure,RPG,Casual,Action         $21.96
# 7202           Action,Adventure,Casual,Indie,RPG            NaN
# 7203           Action,Adventure,Casual,Indie,RPG            NaN
# 7557           Action,Adventure,Casual,Indie,RPG            NaN
# 7699           Action,Adventure,Casual,Indie,RPG            NaN
# 7850           Adventure,Casual,Indie,RPG,Action            NaN
# 8057           Adventure,Casual,Indie,RPG,Action            NaN
#
#      discount_price     review_qualification  percentage_positive_review  \
# 73           $29.56  Overwhelmingly Positive                          96
# 964           $6.99            Very Positive                          84
# 1161         $79.84            Very Positive                          85
# 2308         $70.28            Very Positive                          92
# 3432            NaN            Very Positive                          81
# 4016            NaN            Very Positive                          95
# 4457         $32.56            Very Positive                          92
# 4481         $79.84                      NaN                          -1
# 5886          $5.70                    Mixed                          68
# 5951         $54.96                      NaN                          -1
# 6408         $69.23                      NaN                          -1
# 6824          $7.51                      NaN                          -1
# 7030         $32.56                    Mixed                          68
# 7135          $9.15                      NaN                          -1
# 7202          $5.37                      NaN                          -1
# 7203         $28.00                      NaN                          -1
# 7557         $70.28                      NaN                          -1
# 7699         $23.73                      NaN                          -1
# 7850         $16.17                      NaN                          -1
# 8057         $14.45                      NaN                          -1
#
#                                             ID  \
# 73                              castlecrashers
# 964                                 bladedfury
# 1161                               timespinner
# 2308                              bookofdemons
# 3432                  agesofmagesthelastkeeper
# 4016                                   arafell
# 4457                dabmanwhenthehatersdabback
# 4481                  chucklefishfriendsbundle
# 5886                                lootherodx
# 5951                         xgenstudiosbundle
# 6408             theblackwhiteindiegamesbundle
# 6824                         statelysnailgames
# 7030                 aidsmojitheforbiddenfruit
# 7135                            doomsterbundle
# 7202               campsunshineultimateedition
# 7203                         capslockdaybundle
# 7557       bookofdemonstosupporterspackupgrade
# 7699       supercanemagiczerosoundtrackedition
# 7850  starstorygameostartbookdevssupportbundle
# 8057                   supernaturalindiebundle
#
#                               genre_publisher_developer
# 73        Adventure,Action,Indie,RPG,Casual,TheBehemoth
# 964       Adventure,Action,Indie,RPG,NEXTStudios,Casual
# 1161  Adventure,Action,Chucklefish,Indie,RPG,LunarRa...
# 2308       Adventure,ThingTrunk,Action,Indie,RPG,Casual
# 3432         YFCgames,Adventure,Action,Indie,RPG,Casual
# 4016   StegosoftGames,Adventure,Action,Indie,RPG,Casual
# 4457        Adventure,Action,Indie,RPG,Casual,BmcStudio
# 4481  Adventure,Action,Chucklefish,Indie,RPG,Robotal...
# 5886          Adventure,Action,VaragtP,Indie,RPG,Casual
# 5951      Adventure,XGenStudios,Action,Indie,RPG,Casual
# 6408         Adventure,Playdead,Action,Indie,RPG,Casual
# 6824     Adventure,Action,StatelySnail,Indie,RPG,Casual
# 7030        Adventure,Action,Indie,RPG,Casual,BmcStudio
# 7135  Adventure,Action,Indie,RPG,DoomsterEntertainme...
# 7202      Adventure,Action,Indie,RPG,FossilGames,Casual
# 7203       Adventure,DylanLoney,Action,Indie,RPG,Casual
# 7557       Adventure,ThingTrunk,Action,Indie,RPG,Casual
# 7699       Adventure,Action,Indie,RPG,StudioEvil,Casual
# 7850      Adventure,Action,Indie,RPG,Casual,EvilCoGames
# 8057  Adventure,Action,Indie,RPG,Casual,AsteristicGa...
